# %%
import numpy as np

# %%
import time

# %% [markdown]
# **time with normal python (without numpy)**

# %%
size=10000000
list1=list(range(size))
list2=list(range(size))

start=time.time()
add=[x+y for x,y in zip(list1,list2)]
end=time.time()
print(end-start)
# Out:
# 1.9550106525421143

# %%
size=10000000
list1=list(range(size))

start=time.time()
square=[x*x for x in list1]
end=time.time()
print(end-start)
# Out:
# 1.4815943241119385

# %% [markdown]
# **time with numpy**

# %%
size=10000000
list1=np.array(list(range(size)))
list2=np.array(list(range(size)))

start=time.time()
add=list1+list2
end=time.time()
print(end-start)
# Out:
# 0.3440239429473877

# %%
size=10000000
list1=np.array(list(range(size)))


start=time.time()
square=list1 ** 2
end=time.time()
print(end-start)
# Out:
# 0.039763450622558594
