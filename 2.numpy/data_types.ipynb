# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr2=arr.astype("float64")

# %%
arr2.dtype
# Out:
# dtype('float64')

# %%
arr.nbytes
# Out:
# 40

# %%
arr2.nbytes
# Out:
# 40

# %% [markdown]
# **complex number**

# %%
cn=np.array([2+1j,1+2j],dtype='complex128')

# %%
cn
# Out:
# array([2.+1.j, 1.+2.j])
