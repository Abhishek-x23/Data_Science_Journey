# %%
import numpy as np

# %% [markdown]
# **2D array**

# %%
arr=np.array([[1,2,3],[3,5,6],[1,4,6]])
arr
# Out:
# array([[1, 2, 3],
#        [3, 5, 6],
#        [1, 4, 6]])

# %%
# in 2 d array axis =0 -> row and axis=1 -> col
np.sum(arr,axis=0)
# Out:
# array([ 5, 11, 15])

# %%
np.sum(arr,axis=1)
# Out:
# array([ 6, 14, 11])

# %%
arr[2,1]
# Out:
# np.int64(4)

# %%
arr[0:1,1:3]
# Out:
# array([[2, 3]])

# %% [markdown]
# **3D array**

# %%
arr=np.array([[[1,2,3],[4,5,6]],[[11,22,33],[44,55,66]],[[12,13,14],[15,16,17]]])

# %%
arr
# Out:
# array([[[ 1,  2,  3],
#         [ 4,  5,  6]],
#
#        [[11, 22, 33],
#         [44, 55, 66]],
#
#        [[12, 13, 14],
#         [15, 16, 17]]])

# %%
arr[0,1,1]
# Out:
# np.int64(5)

# %%
arr[1:,0:2,:2]
# Out:
# array([[[11, 22],
#         [44, 55]],
#
#        [[12, 13],
#         [15, 16]]])
