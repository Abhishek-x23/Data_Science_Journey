# %%
import numpy as np

# %%
arr=np.array([1,4,2,88,19,12,0])
arr.astype("int32")
# Out:
# array([ 1,  4,  2, 88, 19, 12,  0], dtype=int32)

# %%
arr2=np.array([1,23,90,5,23,5,6])
arr2.astype("int32")
# Out:
# array([ 1, 23, 90,  5, 23,  5,  6], dtype=int32)

# %%
arr.max()
# Out:
# np.int64(88)

# %%
print(arr.min())
# Out:
# 0

# %%
arr.argmax()
# Out:
# np.int64(3)

# %%
arr.argmin()
# Out:
# np.int64(6)

# %%
arr.sum()
# Out:
# np.int64(126)

# %%
arr.prod()
# Out:
# np.int64(0)

# %%
np.median(arr)
# Out:
# np.float64(4.0)

# %%
np.mean(arr)
# Out:
# np.float64(18.0)

# %%
np.std(arr)
# Out:
# np.float64(29.281881282263466)

# %%
np.var(arr)
# Out:
# np.float64(857.4285714285714)

# %%
np.percentile(arr,19)
# Out:
# np.float64(1.1400000000000001)

# %%
np.percentile(arr,5)
# Out:
# np.float64(0.30000000000000004)

# %%
np.log(arr)
# Out:
# C:\Users\ABHISHEK\AppData\Local\Temp\ipykernel_25188\3120950136.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(arr)
# array([0.        , 1.38629436, 0.69314718, 4.47733681, 2.94443898,
#        2.48490665,       -inf])

# %%
np.exp(arr)
# Out:
# array([2.71828183e+00, 5.45981500e+01, 7.38905610e+00, 1.65163625e+38,
#        1.78482301e+08, 1.62754791e+05, 1.00000000e+00])

# %%
np.cumsum(arr)
# Out:
# array([  1,   5,   7,  95, 114, 126, 126])

# %%
np.diff(arr)
# Out:
# array([  3,  -2,  86, -69,  -7, -12])

# %%
np.unique(arr2)
# Out:
# array([ 1,  5,  6, 23, 90])

# %%
np.corrcoef(arr,arr2)
# Out:
# array([[ 1.        , -0.25944288],
#        [-0.25944288,  1.        ]])
