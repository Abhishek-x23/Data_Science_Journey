# %%
a=11

# %%
b=12

# %%
a//b
# Out:
# 0

# %%
a=2

# %%
b=3

# %%
a**b
# Out:
# 8

# %%
b**a
# Out:
# 9

# %%
a=5
b=3
print(a&b)
print(a | b)
# Out:
# 1
# 7

# %%
print(a^b)
print(~b)
# Out:
# 6
# -4

# %%
print(b>>1)
print(b<<1)
# Out:
# 1
# 6

# %%
arr=[2,4,6,8]

# %%
3 in arr
# Out:
# False

# %%
3  not in arr
# Out:
# True

# %%
[3,5] in arr
# Out:
# False

# %%
[2,4] in arr
# Out:
# False

# %%
2 not in arr
# Out:
# False

# %%
age = input("enter your age ")
# Out:
# enter your age  21

# %%
her_age= input("enter her age ")
# Out:
# enter her age  20

# %%
age+her_age
# Out:
# '2120'

# %%
int(age)+int(her_age)
# Out:
# 41
