# %%
his = "abhishek"

# %%
her="barsha"

# %%
his[1]
# Out:
# 'b'

# %%
her[0]
# Out:
# 'b'

# %%
print(f"{her} loves and she is obsessed with {his}")
# Out:
# barsha loves and she is obsessed with abhishek

# %%
her[0]="sneha"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 her[0]="sneha"
#
# TypeError: 'str' object does not support item assignment

# %%
her
# Out:
# 'sneha'

# %%
print(f"{his:<10}")
print(f"{her:>10}")
# Out:
# abhishek
#     barsha

# %%
print("{} dominates {}".format(his,her))
# Out:
# abhishek dominates barsha

# %%
print("{name} is {age} years old".format(name="abhishek",age="21"))
# Out:
# abhishek is 21 years old

# %%
list =["abhishek","sneha","barsha","snihita","anushka","prachi","arunita","homa","rudrani"]

# %%
for p in list:
    print(p)
# Out:
# abhishek
# sneha
# barsha
# snihita
# anushka
# prachi
# arunita
# homa
# rudrani

# %%
for p in list:
    if(p=="prachi"):
        continue
    elif(p=="homa"):
        break
    print(p)
# Out:
# abhishek
# sneha
# barsha
# snihita
# anushka
# arunita

# %%
for i in range(5,10):
    
    pass
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9
