# %%
age= int(input("enter age "))
# Out:
# enter age  21

# %%
def eligible(age):
    if(age>=18):
        print("You are eligible to vote")
    elif(age<18 and age>=0):
        print("you ar enot eligible to vote")
        print("wait for ",18-age," years")
    else:
        print("kyu backchodi kr rha hai ")

# %%
eligible(age)
# Out:
# You are eligible to vote

# %%
eligible(4)
# Out:
# you ar enot eligible to vote
# wait for  14  years

# %%
eligible(-2)
# Out:
# kyu backchodi kr rha hai
