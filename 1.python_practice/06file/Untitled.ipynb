# %%
dic={}

# %%
type(dic)
# Out:
# dict

# %%
dic={"name":"abhishek","age":21,"gf":"barsha"}

# %%
dict["name"]
# Out:
# dict['name']

# %%
dic["name"]
# Out:
# 'abhishek'

# %%
dic.get("name")
# Out:
# 'abhishek'

# %%
print(dic.get("scheeol"))
# Out:
# None

# %%
dic.get("school","not found ")
# Out:
# 'not found '

# %%
dic2={"name":"barsha","age":21,"bf":"abhishek"}

# %%
dic.keys()
# Out:
# dict_keys(['name', 'age', 'gf'])

# %%
dic2.keys()
# Out:
# dict_keys(['name', 'age', 'bf'])

# %%
dic2.values()
# Out:
# dict_values(['barsha', 21, 'abhishek'])

# %%
dic.items()
# Out:
# dict_items([('name', 'abhishek'), ('age', 21), ('gf', 'barsha')])

# %%
dic2.items()
# Out:
# dict_items([('name', 'barsha'), ('age', 21), ('bf', 'abhishek')])

# %%
dic.update({"type":"lusty"})

# %%
d={"a":2,"b":3,"c":7}

# %%
d.pop("c")
# Out:
# 7

# %%
d
# Out:
# {'a': 2, 'b': 3}

# %%
d.update({"b":1})

# %%
d.pop("c","not found babe")
# Out:
# 'not found babe'

# %%
d.popitem()
# Out:
# ('b', 3)

# %%
d
# Out:
# {'a': 2, 'b': 1}

# %%
d.update({"b":4})

# %%
d
# Out:
# {'a': 2, 'b': 4}

# %%
d2={}

# %%
d2= d.copy()

# %%
d.setdefault("b","not found babe")
# Out:
# 4

# %%
d.setdefault("x","not found babe")
# Out:
# 'not found babe'

# %%
d2
# Out:
# {'a': 2, 'b': 4, 'x': 'not found babe'}

# %%
d
# Out:
# {'a': 2, 'b': 4, 'x': 'not found babe'}
