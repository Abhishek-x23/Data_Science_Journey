# %%
f = open("text.txt","r")

# %%
a=f.read()

# %%
s="Namaste Bharat"

# %%
f.close()

# %%
f2=open("text2.txt","w")

# %%
f2.write(a)
# Out:
# 12

# %%
f2.write("hello world")
# Out:
# 11

# %%
f2.close()

# %%
f3=open("text2.txt","r")

# %%
lines=f3.readlines()

# %%
lines
# Out:
# ['Hello World\n', 'namaste india\n', 'nomoskar kolkata\n', '\n']

# %%
lines[1]
# Out:
# 'namaste india\n'

# %%
type(lines)
# Out:
# list

# %%
f4=open("text4.txt","w")

# %%
f4.write("hello world")
# Out:
# 11

# %%
f4.close()

# %%
f4=open("text4.txt","a")

# %%
f4.write("jai shree Ram")
# Out:
# 13

# %%
f5 = open("text4.txt", "r")
fd5 = f5.read()

print(fd5)

f6 = open("text5.txt", "w")
f6.write(fd5)

f5.close()
f6.close()
# Out:
# hello worldjai shree Ram

# %%
f5=open("text4.txt","r")
fd5=f5.read()
print(fd5)
# Out:
# hello worldjai shree Ram
