# %%
print("hello world")
# Out:
# hello world

# %%
a=3

# %%
b=7

# %%
c=a+b

# %%
c
# Out:
# '4533'

# %%
a="45"

# %%
b="33"

# %%
c=a+b

# %%
c
# Out:
# '4533'

# %%
c=int(a)+int(b)
print(c)
# Out:
# 78

# %%
a="abhishek"

# %%
a.capitalize()
# Out:
# 'Abhishek'

# %%
a.capitalize
# Out:
# <function str.capitalize()>

# %%
a.endswith("jk")
# Out:
# False

# %%
a.endswith("ek")
# Out:
# True

# %%
a.count("b")
# Out:
# 1

# %%
a
# Out:
# 'abhishek'

# %%
b="  barsha  "

# %%
b.strip()
# Out:
# 'barsha'

# %%
b.find("a")
# Out:
# 3

# %%
b.replace("ha","habhishek")
# Out:
# '  barshabhishek  '

# %%
b
# Out:
# '  barsha  '

# %%
c="a b c"

# %%
c.split()
# Out:
# ['a', 'b', 'c']

# %%
c="abs"

# %%
c.split("b")
# Out:
# ['a', 's']

# %%
c.isdigit()
# Out:
# False

# %%
c.isalpha()
# Out:
# True
