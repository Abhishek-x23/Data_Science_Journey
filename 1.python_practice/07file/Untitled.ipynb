# %%
s1=set([2,4,1,5,1,2,8,9])

# %%
s1
# Out:
# {1, 2, 4, 5, 8, 9}

# %%
s2=set([3,2,5,7,0,2,34])

# %%
s1.intersection(s2)
# Out:
# {2, 5}

# %%
s1.union(s2)
# Out:
# {0, 1, 2, 3, 4, 5, 7, 8, 9, 34}

# %%
s1.difference(s2)
# Out:
# {1, 4, 8, 9}

# %%
s3=set([2,3])

# %%
s3.issubset(s1.union(s2))
# Out:
# True

# %%
s4=set([1,4])

# %%
s1.issuperset(s4)
# Out:
# True

# %%
s4.isdisjoint(s3)
# Out:
# True

# %%
s5=set()

# %%
s5.update([1,2,3,4,5,6,7,8])

# %%
s5.remove(3)

# %%
s5
# Out:
# {1, 2, 4, 5, 6, 7, 8}

# %%
s5.update([3,9,8])

# %%
s5
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s5.discard(10)

# %%
s5.pop()
# Out:
# 1

# %%
s5.pop()
# Out:
# 2

# %%
s5.pop()
# Out:
# 3

# %%
s5.add(3)

# %%
s5
# Out:
# {3, 4, 5, 6, 7, 8, 9}

# %%
s5.clear()

# %%
s5
# Out:
# set()
